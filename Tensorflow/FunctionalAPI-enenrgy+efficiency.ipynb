# %% [markdown]
# <a href="https://colab.research.google.com/github/aim97/Neural-networks/blob/master/Tensorflow/FunctionalAPI-enenrgy%2Befficiency.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tensorflow Functional API
#
# Tensorflow adds more flexibility of defining the model using its functional API.
#
# If your model is simply staking layers on top of one another, you only need to use `Sequential` Model, which will do the job for you. However if your code is more complicated taking different paths, and then rejoining, or having multiple different outputs, the usual sequential model wouldn't cut it and you would need a more flexible way to define your model.
#
# That's where the functional API comes for the rescue, it allows you to connect layers manually rather than having Sequential connect them for you, which allows you to connect your neural network in all sorts of ways.
#
# In order to build such model, Tensorflow requires you to provide 2 Things:
#
# 1. The model input(s).
# 2. The model output(s).
#
# and provide them to `Model` class constructor, then from this point forward everything is like how it's done with Sequential.

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Input
import numpy as np

# %% [markdown]
# What you need to understand is mainly how to connect layer with the functional API.
# ```python
# layer2_output = LayerConstructor( ...layer_parameters ) (layer1_output)
# ```
#
# You form a connection better two layers in this way.

# %%
xs = Input((8,), name='model_input')
x = Dense(128, activation='relu', name='first')(xs)
x = Dense(128, activation='relu', name='second')(x)

y1 = Dense(1, name='y1_output')(x);
y2_path = Dense(64, activation='relu', name='another_path')(x)

y2 = Dense(1, name='y2_output')(y2_path)

# %%
model = tf.keras.Model(inputs=[xs], outputs=[y1, y2])  # when you have multiple output specifiy them all
# notice the names of the layers displayed in the summary
print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# model_input (InputLayer)        [(None, 8)]          0
# __________________________________________________________________________________________________
# first (Dense)                   (None, 128)          1152        model_input[0][0]
# __________________________________________________________________________________________________
# second (Dense)                  (None, 128)          16512       first[0][0]
# __________________________________________________________________________________________________
# another_path (Dense)            (None, 64)           8256        second[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         second[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          another_path[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# Note: with Tensorflow functional API, when you have multiple outputs, giving the output layer a name is important, actually it's a good practice to give each layer a unique (it has to be unique) name to identify it.
#
# 1. It makes it easier to understand the model summary and model graph.
# 2. Multiple parts of tensorflow API use those names, for instance, in our case we want to define different loss and metrics of performance for each output we have, we provide a dictionary with the output layers **names** as keys.
#
# ```python
# model.compile(
#     optimizer=optimizer,
#     loss={
#         'y1_output': 'mse',
#         'y2_output': 'mse'
#     },
#     metrics={
#         'y1_output': tf.keras.metrics.RootMeanSquaredError(),
#         'y2_output': tf.keras.metrics.RootMeanSquaredError()
#     }
# )
# ```
#
# You can also use a list to do the job which will depend on the order the outputs appear in the outputs list provided to the model constructor, but using a dictionary provides higher readability.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(learning_rate=0.001)

model.compile(
    optimizer=optimizer,
    loss=[
        'mse', 
        'mse'
    ],
    metrics=[
        [tf.keras.metrics.RootMeanSquaredError()],
        [tf.keras.metrics.RootMeanSquaredError()]
    ]
)

# %% [markdown]
# We use sklearn `train_test_split` to split our dataset with a given ratio.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
# read the energy + efficiency data set from its URL
dataset = pd.read_excel('https://archive.ics.uci.edu/ml/machine-learning-databases/00242/ENB2012_data.xlsx');
# suffule the dataset, then reset the index column since we don't want it suffuled as well.
dataset = dataset.sample(frac=1).reset_index(drop=True)

# %% [markdown]
# ## Some Cleanup
#
# Aside from splitting the dataset into training and testing sets, we also need to split it into input and output, which is done by the `format_output` helper function.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']

# %%
# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(dataset, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %%
# Train the model for 500 epochs
history = model.fit(
    norm_train_X, 
    np.array(train_Y).T,
    epochs=500, 
    batch_size=10, 
    validation_data=(norm_test_X, test_Y)
)
# Out:
# Epoch 1/500
# 62/62 [==============================] - 2s 8ms/step - loss: 238.5815 - y1_output_loss: 126.2309 - y2_output_loss: 112.3506 - y1_output_root_mean_squared_error: 11.2353 - y2_output_root_mean_squared_error: 10.5996 - val_loss: 71.0435 - val_y1_output_loss: 24.2798 - val_y2_output_loss: 46.7637 - val_y1_output_root_mean_squared_error: 4.9275 - val_y2_output_root_mean_squared_error: 6.8384
# Epoch 2/500
# 62/62 [==============================] - 0s 3ms/step - loss: 33.0037 - y1_output_loss: 14.6073 - y2_output_loss: 18.3963 - y1_output_root_mean_squared_error: 3.8220 - y2_output_root_mean_squared_error: 4.2891 - val_loss: 32.3142 - val_y1_output_loss: 14.4419 - val_y2_output_loss: 17.8723 - val_y1_output_root_mean_squared_error: 3.8002 - val_y2_output_root_mean_squared_error: 4.2276
# Epoch 3/500
# 62/62 [==============================] - 0s 3ms/step - loss: 29.6875 - y1_output_loss: 13.0723 - y2_output_loss: 16.6152 - y1_output_root_mean_squared_error: 3.6156 - y2_output_root_mean_squared_error: 4.0762 - val_loss: 32.6444 - val_y1_output_loss: 13.0221 - val_y2_output_loss: 19.6223 - val_y1_output_root_mean_squared_error: 3.6086 - val_y2_output_root_mean_squared_error: 4.4297
# Epoch 4/500
# 62/62 [==============================] - 0s 3ms/step - loss: 26.1262 - y1_output_loss: 12.0047 - y2_output_loss: 14.1215 - y1_output_root_mean_squared_error: 3.4648 - y2_output_root_mean_squared_error: 3.7579 - val_loss: 26.3609 - val_y1_output_loss: 13.0171 - val_y2_output_loss: 13.3438 - val_y1_output_root_mean_squared_error: 3.6079 - val_y2_output_root_mean_squared_error: 3.6529
# Epoch 5/500
# 62/62 [==============================] - 0s 3ms/step - loss: 27.2402 - y1_output_loss: 12.1143 - y2_output_loss: 15.1259 - y1_output_root_mean_squared_error: 3.4806 - y2_output_root_mean_squared_error: 3.8892 - val_loss: 53.5915 - val_y1_output_loss: 20.0136 - val_y2_output_loss: 33.5779 - val_y1_output_root_mean_squared_error: 4.4737 - val_y2_output_root_mean_squared_error: 5.7946
# Epoch 6/500
# 62/62 [==============================] - 0s 3ms/step - loss: 26.5681 - y1_output_loss: 11.8526 - y2_output_loss: 14.7156 - y1_output_root_mean_squared_error: 3.4428 - y2_output_root_mean_squared_error: 3.8361 - val_loss: 78.4841 - val_y1_output_loss: 28.8245 - val_y2_output_loss: 49.6595 - val_y1_output_root_mean_squared_error: 5.3688 - val_y2_output_root_mean_squared_error: 7.0470
# Epoch 7/500
# 62/62 [==============================] - 0s 3ms/step - loss: 26.7049 - y1_output_loss: 11.8498 - y2_output_loss: 14.8551 - y1_output_root_mean_squared_error: 3.4424 - y2_output_root_mean_squared_error: 3.8542 - val_loss: 41.3010 - val_y1_output_loss: 12.3587 - val_y2_output_loss: 28.9423 - val_y1_output_root_mean_squared_error: 3.5155 - val_y2_output_root_mean_squared_error: 5.3798
# Epoch 8/500
# 62/62 [==============================] - 0s 3ms/step - loss: 25.1970 - y1_output_loss: 11.3850 - y2_output_loss: 13.8119 - y1_output_root_mean_squared_error: 3.3742 - y2_output_root_mean_squared_error: 3.7164 - val_loss: 30.2476 - val_y1_output_loss: 14.5438 - val_y2_output_loss: 15.7038 - val_y1_output_root_mean_squared_error: 3.8136 - val_y2_output_root_mean_squared_error: 3.9628
# Epoch 9/500
# 62/62 [==============================] - 0s 3ms/step - loss: 23.8692 - y1_output_loss: 11.0368 - y2_output_loss: 12.8324 - y1_output_root_mean_squared_error: 3.3222 - y2_output_root_mean_squared_error: 3.5822 - val_loss: 22.9552 - val_y1_output_loss: 11.5558 - val_y2_output_loss: 11.3994 - val_y1_output_root_mean_squared_error: 3.3994 - val_y2_output_root_mean_squared_error: 3.3763
# Epoch 10/500
# 62/62 [==============================] - 0s 3ms/step - loss: 22.1279 - y1_output_loss: 10.5189 - y2_output_loss: 11.6090 - y1_output_root_mean_squared_error: 3.2433 - y2_output_root_mean_squared_error: 3.4072 - val_loss: 56.6172 - val_y1_output_loss: 23.2726 - val_y2_output_loss: 33.3446 - val_y1_output_root_mean_squared_error: 4.8242 - val_y2_output_root_mean_squared_error: 5.7745
# Epoch 11/500
# 62/62 [==============================] - 0s 3ms/step - loss: 24.5615 - y1_output_loss: 11.1323 - y2_output_loss: 13.4292 - y1_output_root_mean_squared_error: 3.3365 - y2_output_root_mean_squared_error: 3.6646 - val_loss: 20.4968 - val_y1_output_loss: 10.7669 - val_y2_output_loss: 9.7299 - val_y1_output_root_mean_squared_error: 3.2813 - val_y2_output_root_mean_squared_error: 3.1193
# Epoch 12/500
# 62/62 [==============================] - 0s 3ms/step - loss: 26.0302 - y1_output_loss: 11.3434 - y2_output_loss: 14.6867 - y1_output_root_mean_squared_error: 3.3680 - y2_output_root_mean_squared_error: 3.8323 - val_loss: 23.0006 - val_y1_output_loss: 12.1169 - val_y2_output_loss: 10.8838 - val_y1_output_root_mean_squared_error: 3.4809 - val_y2_output_root_mean_squared_error: 3.2991
# Epoch 13/500
# 62/62 [==============================] - 0s 2ms/step - loss: 23.8881 - y1_output_loss: 10.6508 - y2_output_loss: 13.2373 - y1_output_root_mean_squared_error: 3.2636 - y2_output_root_mean_squared_error: 3.6383 - val_loss: 25.1108 - val_y1_output_loss: 14.1143 - val_y2_output_loss: 10.9965 - val_y1_output_root_mean_squared_error: 3.7569 - val_y2_output_root_mean_squared_error: 3.3161
# Epoch 14/500
# 62/62 [==============================] - 0s 3ms/step - loss: 23.6465 - y1_output_loss: 10.5550 - y2_output_loss: 13.0915 - y1_output_root_mean_squared_error: 3.2488 - y2_output_root_mean_squared_error: 3.6182 - val_loss: 28.0006 - val_y1_output_loss: 8.8216 - val_y2_output_loss: 19.1789 - val_y1_output_root_mean_squared_error: 2.9701 - val_y2_output_root_mean_squared_error: 4.3794
# Epoch 15/500
# 62/62 [==============================] - 0s 3ms/step - loss: 23.6120 - y1_output_loss: 10.6267 - y2_output_loss: 12.9852 - y1_output_root_mean_squared_error: 3.2599 - y2_output_root_mean_squared_error: 3.6035 - val_loss: 21.5855 - val_y1_output_loss: 11.7534 - val_y2_output_loss: 9.8322 - val_y1_output_root_mean_squared_error: 3.4283 - val_y2_output_root_mean_squared_error: 3.1356
# Epoch 16/500
# 62/62 [==============================] - 0s 4ms/step - loss: 21.4351 - y1_output_loss: 9.9268 - y2_output_loss: 11.5083 - y1_output_root_mean_squared_error: 3.1507 - y2_output_root_mean_squared_error: 3.3924 - val_loss: 19.7925 - val_y1_output_loss: 10.1780 - val_y2_output_loss: 9.6145 - val_y1_output_root_mean_squared_error: 3.1903 - val_y2_output_root_mean_squared_error: 3.1007
# Epoch 17/500
# 62/62 [==============================] - 0s 3ms/step - loss: 21.1465 - y1_output_loss: 9.7916 - y2_output_loss: 11.3550 - y1_output_root_mean_squared_error: 3.1291 - y2_output_root_mean_squared_error: 3.3697 - val_loss: 36.0641 - val_y1_output_loss: 15.2172 - val_y2_output_loss: 20.8469 - val_y1_output_root_mean_squared_error: 3.9009 - val_y2_output_root_mean_squared_error: 4.5658
# Epoch 18/500
# 62/62 [==============================] - 0s 3ms/step - loss: 21.7402 - y1_output_loss: 9.7794 - y2_output_loss: 11.9608 - y1_output_root_mean_squared_error: 3.1272 - y2_output_root_mean_squared_error: 3.4584 - val_loss: 42.0144 - val_y1_output_loss: 12.7661 - val_y2_output_loss: 29.2483 - val_y1_output_root_mean_squared_error: 3.5730 - val_y2_output_root_mean_squared_error: 5.4082
# Epoch 19/500
# 62/62 [==============================] - 0s 3ms/step - loss: 21.6570 - y1_output_loss: 9.8006 - y2_output_loss: 11.8564 - y1_output_root_mean_squared_error: 3.1306 - y2_output_root_mean_squared_error: 3.4433 - val_loss: 18.1528 - val_y1_output_loss: 9.8322 - val_y2_output_loss: 8.3206 - val_y1_output_root_mean_squared_error: 3.1356 - val_y2_output_root_mean_squared_error: 2.8845
# Epoch 20/500
# 62/62 [==============================] - 0s 3ms/step - loss: 21.8069 - y1_output_loss: 9.7833 - y2_output_loss: 12.0236 - y1_output_root_mean_squared_error: 3.1278 - y2_output_root_mean_squared_error: 3.4675 - val_loss: 30.2060 - val_y1_output_loss: 8.7059 - val_y2_output_loss: 21.5001 - val_y1_output_root_mean_squared_error: 2.9506 - val_y2_output_root_mean_squared_error: 4.6368
# Epoch 21/500
# 62/62 [==============================] - 0s 3ms/step - loss: 18.3290 - y1_output_loss: 8.6257 - y2_output_loss: 9.7034 - y1_output_root_mean_squared_error: 2.9369 - y2_output_root_mean_squared_error: 3.1150 - val_loss: 23.9210 - val_y1_output_loss: 11.8193 - val_y2_output_loss: 12.1017 - val_y1_output_root_mean_squared_error: 3.4379 - val_y2_output_root_mean_squared_error: 3.4787
# Epoch 22/500
# 62/62 [==============================] - 0s 3ms/step - loss: 19.6895 - y1_output_loss: 8.8692 - y2_output_loss: 10.8203 - y1_output_root_mean_squared_error: 2.9781 - y2_output_root_mean_squared_error: 3.2894 - val_loss: 18.6800 - val_y1_output_loss: 10.2519 - val_y2_output_loss: 8.4281 - val_y1_output_root_mean_squared_error: 3.2019 - val_y2_output_root_mean_squared_error: 2.9031
# Epoch 23/500
# 62/62 [==============================] - 0s 3ms/step - loss: 17.9018 - y1_output_loss: 8.4517 - y2_output_loss: 9.4501 - y1_output_root_mean_squared_error: 2.9072 - y2_output_root_mean_squared_error: 3.0741 - val_loss: 17.7287 - val_y1_output_loss: 9.3161 - val_y2_output_loss: 8.4125 - val_y1_output_root_mean_squared_error: 3.0522 - val_y2_output_root_mean_squared_error: 2.9004
# Epoch 24/500
# 62/62 [==============================] - 0s 3ms/step - loss: 18.6129 - y1_output_loss: 8.6032 - y2_output_loss: 10.0096 - y1_output_root_mean_squared_error: 2.9331 - y2_output_root_mean_squared_error: 3.1638 - val_loss: 22.4146 - val_y1_output_loss: 7.1504 - val_y2_output_loss: 15.2641 - val_y1_output_root_mean_squared_error: 2.6740 - val_y2_output_root_mean_squared_error: 3.9069
# Epoch 25/500
# 62/62 [==============================] - 0s 3ms/step - loss: 20.1242 - y1_output_loss: 8.8908 - y2_output_loss: 11.2334 - y1_output_root_mean_squared_error: 2.9817 - y2_output_root_mean_squared_error: 3.3516 - val_loss: 22.5038 - val_y1_output_loss: 10.7847 - val_y2_output_loss: 11.7191 - val_y1_output_root_mean_squared_error: 3.2840 - val_y2_output_root_mean_squared_error: 3.4233
# Epoch 26/500
# 62/62 [==============================] - 0s 3ms/step - loss: 16.7573 - y1_output_loss: 7.9022 - y2_output_loss: 8.8551 - y1_output_root_mean_squared_error: 2.8111 - y2_output_root_mean_squared_error: 2.9758 - val_loss: 20.7273 - val_y1_output_loss: 6.4982 - val_y2_output_loss: 14.2291 - val_y1_output_root_mean_squared_error: 2.5492 - val_y2_output_root_mean_squared_error: 3.7721
# Epoch 27/500
# 62/62 [==============================] - 0s 3ms/step - loss: 18.8342 - y1_output_loss: 8.2856 - y2_output_loss: 10.5486 - y1_output_root_mean_squared_error: 2.8785 - y2_output_root_mean_squared_error: 3.2479 - val_loss: 15.8205 - val_y1_output_loss: 7.9829 - val_y2_output_loss: 7.8376 - val_y1_output_root_mean_squared_error: 2.8254 - val_y2_output_root_mean_squared_error: 2.7996
# Epoch 28/500
# 62/62 [==============================] - 0s 3ms/step - loss: 15.9769 - y1_output_loss: 7.5396 - y2_output_loss: 8.4373 - y1_output_root_mean_squared_error: 2.7458 - y2_output_root_mean_squared_error: 2.9047 - val_loss: 21.0503 - val_y1_output_loss: 6.3829 - val_y2_output_loss: 14.6674 - val_y1_output_root_mean_squared_error: 2.5264 - val_y2_output_root_mean_squared_error: 3.8298
# Epoch 29/500
# 62/62 [==============================] - 0s 3ms/step - loss: 17.3397 - y1_output_loss: 7.9601 - y2_output_loss: 9.3796 - y1_output_root_mean_squared_error: 2.8214 - y2_output_root_mean_squared_error: 3.0626 - val_loss: 14.7384 - val_y1_output_loss: 6.8017 - val_y2_output_loss: 7.9367 - val_y1_output_root_mean_squared_error: 2.6080 - val_y2_output_root_mean_squared_error: 2.8172
# Epoch 30/500
# 62/62 [==============================] - 0s 3ms/step - loss: 15.5391 - y1_output_loss: 7.2581 - y2_output_loss: 8.2810 - y1_output_root_mean_squared_error: 2.6941 - y2_output_root_mean_squared_error: 2.8777 - val_loss: 13.3061 - val_y1_output_loss: 7.3803 - val_y2_output_loss: 5.9258 - val_y1_output_root_mean_squared_error: 2.7167 - val_y2_output_root_mean_squared_error: 2.4343
# Epoch 31/500
# 62/62 [==============================] - 0s 3ms/step - loss: 17.0930 - y1_output_loss: 7.5714 - y2_output_loss: 9.5216 - y1_output_root_mean_squared_error: 2.7516 - y2_output_root_mean_squared_error: 3.0857 - val_loss: 12.9391 - val_y1_output_loss: 6.4875 - val_y2_output_loss: 6.4515 - val_y1_output_root_mean_squared_error: 2.5471 - val_y2_output_root_mean_squared_error: 2.5400
# Epoch 32/500
# 62/62 [==============================] - 0s 3ms/step - loss: 16.4241 - y1_output_loss: 7.4211 - y2_output_loss: 9.0030 - y1_output_root_mean_squared_error: 2.7242 - y2_output_root_mean_squared_error: 3.0005 - val_loss: 13.7083 - val_y1_output_loss: 4.7641 - val_y2_output_loss: 8.9442 - val_y1_output_root_mean_squared_error: 2.1827 - val_y2_output_root_mean_squared_error: 2.9907
# Epoch 33/500
# 62/62 [==============================] - 0s 3ms/step - loss: 13.9608 - y1_output_loss: 6.6279 - y2_output_loss: 7.3329 - y1_output_root_mean_squared_error: 2.5745 - y2_output_root_mean_squared_error: 2.7079 - val_loss: 44.6688 - val_y1_output_loss: 17.4965 - val_y2_output_loss: 27.1723 - val_y1_output_root_mean_squared_error: 4.1829 - val_y2_output_root_mean_squared_error: 5.2127
# Epoch 34/500
# 62/62 [==============================] - 0s 4ms/step - loss: 17.1649 - y1_output_loss: 7.4367 - y2_output_loss: 9.7282 - y1_output_root_mean_squared_error: 2.7270 - y2_output_root_mean_squared_error: 3.1190 - val_loss: 10.6760 - val_y1_output_loss: 4.9007 - val_y2_output_loss: 5.7753 - val_y1_output_root_mean_squared_error: 2.2138 - val_y2_output_root_mean_squared_error: 2.4032
# Epoch 35/500
# 62/62 [==============================] - 0s 2ms/step - loss: 14.7562 - y1_output_loss: 6.7930 - y2_output_loss: 7.9632 - y1_output_root_mean_squared_error: 2.6063 - y2_output_root_mean_squared_error: 2.8219 - val_loss: 11.3912 - val_y1_output_loss: 5.7612 - val_y2_output_loss: 5.6301 - val_y1_output_root_mean_squared_error: 2.4002 - val_y2_output_root_mean_squared_error: 2.3728
# Epoch 36/500
# 62/62 [==============================] - 0s 3ms/step - loss: 12.9843 - y1_output_loss: 6.1138 - y2_output_loss: 6.8705 - y1_output_root_mean_squared_error: 2.4726 - y2_output_root_mean_squared_error: 2.6212 - val_loss: 10.8402 - val_y1_output_loss: 4.9888 - val_y2_output_loss: 5.8514 - val_y1_output_root_mean_squared_error: 2.2336 - val_y2_output_root_mean_squared_error: 2.4190
# Epoch 37/500
# 62/62 [==============================] - 0s 3ms/step - loss: 14.7086 - y1_output_loss: 6.5763 - y2_output_loss: 8.1323 - y1_output_root_mean_squared_error: 2.5644 - y2_output_root_mean_squared_error: 2.8517 - val_loss: 12.6625 - val_y1_output_loss: 4.7012 - val_y2_output_loss: 7.9613 - val_y1_output_root_mean_squared_error: 2.1682 - val_y2_output_root_mean_squared_error: 2.8216
# Epoch 38/500
# 62/62 [==============================] - 0s 3ms/step - loss: 13.5222 - y1_output_loss: 6.2821 - y2_output_loss: 7.2401 - y1_output_root_mean_squared_error: 2.5064 - y2_output_root_mean_squared_error: 2.6907 - val_loss: 13.1402 - val_y1_output_loss: 7.2013 - val_y2_output_loss: 5.9389 - val_y1_output_root_mean_squared_error: 2.6835 - val_y2_output_root_mean_squared_error: 2.4370
# Epoch 39/500
# 62/62 [==============================] - 0s 3ms/step - loss: 11.5949 - y1_output_loss: 5.6442 - y2_output_loss: 5.9507 - y1_output_root_mean_squared_error: 2.3758 - y2_output_root_mean_squared_error: 2.4394 - val_loss: 13.3706 - val_y1_output_loss: 4.1068 - val_y2_output_loss: 9.2638 - val_y1_output_root_mean_squared_error: 2.0265 - val_y2_output_root_mean_squared_error: 3.0436
# Epoch 40/500
# 62/62 [==============================] - 0s 3ms/step - loss: 12.0707 - y1_output_loss: 5.7144 - y2_output_loss: 6.3563 - y1_output_root_mean_squared_error: 2.3905 - y2_output_root_mean_squared_error: 2.5212 - val_loss: 14.3290 - val_y1_output_loss: 4.9356 - val_y2_output_loss: 9.3934 - val_y1_output_root_mean_squared_error: 2.2216 - val_y2_output_root_mean_squared_error: 3.0649
# Epoch 41/500
# 62/62 [==============================] - 0s 3ms/step - loss: 12.3455 - y1_output_loss: 5.7696 - y2_output_loss: 6.5758 - y1_output_root_mean_squared_error: 2.4020 - y2_output_root_mean_squared_error: 2.5643 - val_loss: 13.6993 - val_y1_output_loss: 4.2107 - val_y2_output_loss: 9.4885 - val_y1_output_root_mean_squared_error: 2.0520 - val_y2_output_root_mean_squared_error: 3.0803
# Epoch 42/500
# 62/62 [==============================] - 0s 3ms/step - loss: 11.8678 - y1_output_loss: 5.5193 - y2_output_loss: 6.3485 - y1_output_root_mean_squared_error: 2.3493 - y2_output_root_mean_squared_error: 2.5196 - val_loss: 10.5402 - val_y1_output_loss: 3.6234 - val_y2_output_loss: 6.9168 - val_y1_output_root_mean_squared_error: 1.9035 - val_y2_output_root_mean_squared_error: 2.6300
# Epoch 43/500
# 62/62 [==============================] - 0s 3ms/step - loss: 10.5067 - y1_output_loss: 5.0983 - y2_output_loss: 5.4084 - y1_output_root_mean_squared_error: 2.2580 - y2_output_root_mean_squared_error: 2.3256 - val_loss: 10.9835 - val_y1_output_loss: 4.7224 - val_y2_output_loss: 6.2611 - val_y1_output_root_mean_squared_error: 2.1731 - val_y2_output_root_mean_squared_error: 2.5022
# Epoch 44/500
# 62/62 [==============================] - 0s 3ms/step - loss: 11.9593 - y1_output_loss: 5.5372 - y2_output_loss: 6.4221 - y1_output_root_mean_squared_error: 2.3531 - y2_output_root_mean_squared_error: 2.5342 - val_loss: 10.4904 - val_y1_output_loss: 4.4678 - val_y2_output_loss: 6.0225 - val_y1_output_root_mean_squared_error: 2.1137 - val_y2_output_root_mean_squared_error: 2.4541
# Epoch 45/500
# 62/62 [==============================] - 0s 3ms/step - loss: 10.1479 - y1_output_loss: 4.9826 - y2_output_loss: 5.1653 - y1_output_root_mean_squared_error: 2.2322 - y2_output_root_mean_squared_error: 2.2727 - val_loss: 11.5536 - val_y1_output_loss: 6.2543 - val_y2_output_loss: 5.2993 - val_y1_output_root_mean_squared_error: 2.5009 - val_y2_output_root_mean_squared_error: 2.3020
# Epoch 46/500
# 62/62 [==============================] - 0s 3ms/step - loss: 10.8459 - y1_output_loss: 5.1440 - y2_output_loss: 5.7019 - y1_output_root_mean_squared_error: 2.2680 - y2_output_root_mean_squared_error: 2.3879 - val_loss: 10.7134 - val_y1_output_loss: 2.8461 - val_y2_output_loss: 7.8673 - val_y1_output_root_mean_squared_error: 1.6870 - val_y2_output_root_mean_squared_error: 2.8049
# Epoch 47/500
# 62/62 [==============================] - 0s 4ms/step - loss: 10.2125 - y1_output_loss: 4.9011 - y2_output_loss: 5.3113 - y1_output_root_mean_squared_error: 2.2139 - y2_output_root_mean_squared_error: 2.3046 - val_loss: 9.7710 - val_y1_output_loss: 3.7262 - val_y2_output_loss: 6.0449 - val_y1_output_root_mean_squared_error: 1.9303 - val_y2_output_root_mean_squared_error: 2.4586
# Epoch 48/500
# 62/62 [==============================] - 0s 3ms/step - loss: 11.0856 - y1_output_loss: 5.1136 - y2_output_loss: 5.9720 - y1_output_root_mean_squared_error: 2.2613 - y2_output_root_mean_squared_error: 2.4438 - val_loss: 13.0107 - val_y1_output_loss: 7.0295 - val_y2_output_loss: 5.9812 - val_y1_output_root_mean_squared_error: 2.6513 - val_y2_output_root_mean_squared_error: 2.4457
# Epoch 49/500
# 62/62 [==============================] - 0s 3ms/step - loss: 10.9491 - y1_output_loss: 5.1083 - y2_output_loss: 5.8408 - y1_output_root_mean_squared_error: 2.2602 - y2_output_root_mean_squared_error: 2.4168 - val_loss: 9.3289 - val_y1_output_loss: 4.9574 - val_y2_output_loss: 4.3715 - val_y1_output_root_mean_squared_error: 2.2265 - val_y2_output_root_mean_squared_error: 2.0908
# Epoch 50/500
# 62/62 [==============================] - 0s 3ms/step - loss: 11.1924 - y1_output_loss: 5.1712 - y2_output_loss: 6.0211 - y1_output_root_mean_squared_error: 2.2740 - y2_output_root_mean_squared_error: 2.4538 - val_loss: 9.9647 - val_y1_output_loss: 4.4783 - val_y2_output_loss: 5.4864 - val_y1_output_root_mean_squared_error: 2.1162 - val_y2_output_root_mean_squared_error: 2.3423
# Epoch 51/500
# 62/62 [==============================] - 0s 3ms/step - loss: 11.4536 - y1_output_loss: 5.2314 - y2_output_loss: 6.2222 - y1_output_root_mean_squared_error: 2.2872 - y2_output_root_mean_squared_error: 2.4944 - val_loss: 10.6441 - val_y1_output_loss: 6.1571 - val_y2_output_loss: 4.4870 - val_y1_output_root_mean_squared_error: 2.4813 - val_y2_output_root_mean_squared_error: 2.1182
# Epoch 52/500
# 62/62 [==============================] - 0s 3ms/step - loss: 10.3100 - y1_output_loss: 4.8772 - y2_output_loss: 5.4328 - y1_output_root_mean_squared_error: 2.2084 - y2_output_root_mean_squared_error: 2.3308 - val_loss: 11.4195 - val_y1_output_loss: 3.0944 - val_y2_output_loss: 8.3251 - val_y1_output_root_mean_squared_error: 1.7591 - val_y2_output_root_mean_squared_error: 2.8853
# Epoch 53/500
# 62/62 [==============================] - 0s 3ms/step - loss: 9.2305 - y1_output_loss: 4.4798 - y2_output_loss: 4.7507 - y1_output_root_mean_squared_error: 2.1166 - y2_output_root_mean_squared_error: 2.1796 - val_loss: 10.2477 - val_y1_output_loss: 3.5104 - val_y2_output_loss: 6.7372 - val_y1_output_root_mean_squared_error: 1.8736 - val_y2_output_root_mean_squared_error: 2.5956
# Epoch 54/500
# 62/62 [==============================] - 0s 3ms/step - loss: 9.7952 - y1_output_loss: 4.6326 - y2_output_loss: 5.1626 - y1_output_root_mean_squared_error: 2.1523 - y2_output_root_mean_squared_error: 2.2721 - val_loss: 10.6333 - val_y1_output_loss: 3.0143 - val_y2_output_loss: 7.6190 - val_y1_output_root_mean_squared_error: 1.7362 - val_y2_output_root_mean_squared_error: 2.7603
# Epoch 55/500
# 62/62 [==============================] - 0s 3ms/step - loss: 10.0133 - y1_output_loss: 4.6503 - y2_output_loss: 5.3630 - y1_output_root_mean_squared_error: 2.1565 - y2_output_root_mean_squared_error: 2.3158 - val_loss: 15.3608 - val_y1_output_loss: 8.1636 - val_y2_output_loss: 7.1971 - val_y1_output_root_mean_squared_error: 2.8572 - val_y2_output_root_mean_squared_error: 2.6827
# Epoch 56/500
# 62/62 [==============================] - 0s 3ms/step - loss: 9.7158 - y1_output_loss: 4.5581 - y2_output_loss: 5.1577 - y1_output_root_mean_squared_error: 2.1350 - y2_output_root_mean_squared_error: 2.2711 - val_loss: 9.0785 - val_y1_output_loss: 4.8491 - val_y2_output_loss: 4.2294 - val_y1_output_root_mean_squared_error: 2.2021 - val_y2_output_root_mean_squared_error: 2.0565
# Epoch 57/500
# 62/62 [==============================] - 0s 3ms/step - loss: 9.7679 - y1_output_loss: 4.5876 - y2_output_loss: 5.1803 - y1_output_root_mean_squared_error: 2.1419 - y2_output_root_mean_squared_error: 2.2760 - val_loss: 10.5938 - val_y1_output_loss: 2.8829 - val_y2_output_loss: 7.7108 - val_y1_output_root_mean_squared_error: 1.6979 - val_y2_output_root_mean_squared_error: 2.7768
# Epoch 58/500
# 62/62 [==============================] - 0s 3ms/step - loss: 9.7284 - y1_output_loss: 4.6126 - y2_output_loss: 5.1158 - y1_output_root_mean_squared_error: 2.1477 - y2_output_root_mean_squared_error: 2.2618 - val_loss: 8.7494 - val_y1_output_loss: 5.2493 - val_y2_output_loss: 3.5001 - val_y1_output_root_mean_squared_error: 2.2911 - val_y2_output_root_mean_squared_error: 1.8708
# Epoch 59/500
# 62/62 [==============================] - 0s 3ms/step - loss: 9.9439 - y1_output_loss: 4.5763 - y2_output_loss: 5.3676 - y1_output_root_mean_squared_error: 2.1392 - y2_output_root_mean_squared_error: 2.3168 - val_loss: 9.2863 - val_y1_output_loss: 4.9117 - val_y2_output_loss: 4.3745 - val_y1_output_root_mean_squared_error: 2.2162 - val_y2_output_root_mean_squared_error: 2.0915
# Epoch 60/500
# 62/62 [==============================] - 0s 3ms/step - loss: 9.4826 - y1_output_loss: 4.4536 - y2_output_loss: 5.0290 - y1_output_root_mean_squared_error: 2.1104 - y2_output_root_mean_squared_error: 2.2425 - val_loss: 17.1073 - val_y1_output_loss: 3.9621 - val_y2_output_loss: 13.1451 - val_y1_output_root_mean_squared_error: 1.9905 - val_y2_output_root_mean_squared_error: 3.6256
# Epoch 61/500
# 62/62 [==============================] - 0s 3ms/step - loss: 9.6062 - y1_output_loss: 4.4866 - y2_output_loss: 5.1196 - y1_output_root_mean_squared_error: 2.1182 - y2_output_root_mean_squared_error: 2.2626 - val_loss: 8.5623 - val_y1_output_loss: 3.0024 - val_y2_output_loss: 5.5599 - val_y1_output_root_mean_squared_error: 1.7327 - val_y2_output_root_mean_squared_error: 2.3579
# Epoch 62/500
# 62/62 [==============================] - 0s 3ms/step - loss: 8.9452 - y1_output_loss: 4.2308 - y2_output_loss: 4.7144 - y1_output_root_mean_squared_error: 2.0569 - y2_output_root_mean_squared_error: 2.1713 - val_loss: 8.3339 - val_y1_output_loss: 3.5582 - val_y2_output_loss: 4.7757 - val_y1_output_root_mean_squared_error: 1.8863 - val_y2_output_root_mean_squared_error: 2.1853
# Epoch 63/500
# 62/62 [==============================] - 0s 3ms/step - loss: 8.4253 - y1_output_loss: 4.0491 - y2_output_loss: 4.3762 - y1_output_root_mean_squared_error: 2.0122 - y2_output_root_mean_squared_error: 2.0919 - val_loss: 9.1977 - val_y1_output_loss: 4.6545 - val_y2_output_loss: 4.5431 - val_y1_output_root_mean_squared_error: 2.1574 - val_y2_output_root_mean_squared_error: 2.1315
# Epoch 64/500
# 62/62 [==============================] - 0s 3ms/step - loss: 7.9644 - y1_output_loss: 3.9105 - y2_output_loss: 4.0538 - y1_output_root_mean_squared_error: 1.9775 - y2_output_root_mean_squared_error: 2.0134 - val_loss: 69.6133 - val_y1_output_loss: 18.1730 - val_y2_output_loss: 51.4403 - val_y1_output_root_mean_squared_error: 4.2630 - val_y2_output_root_mean_squared_error: 7.1722
# Epoch 65/500
# 62/62 [==============================] - 0s 3ms/step - loss: 12.4766 - y1_output_loss: 5.4823 - y2_output_loss: 6.9943 - y1_output_root_mean_squared_error: 2.3414 - y2_output_root_mean_squared_error: 2.6447 - val_loss: 22.2061 - val_y1_output_loss: 10.3119 - val_y2_output_loss: 11.8941 - val_y1_output_root_mean_squared_error: 3.2112 - val_y2_output_root_mean_squared_error: 3.4488
# Epoch 66/500
# 62/62 [==============================] - 0s 3ms/step - loss: 9.4576 - y1_output_loss: 4.3942 - y2_output_loss: 5.0635 - y1_output_root_mean_squared_error: 2.0962 - y2_output_root_mean_squared_error: 2.2502 - val_loss: 17.8357 - val_y1_output_loss: 7.7853 - val_y2_output_loss: 10.0504 - val_y1_output_root_mean_squared_error: 2.7902 - val_y2_output_root_mean_squared_error: 3.1702
# Epoch 67/500
# 62/62 [==============================] - 0s 3ms/step - loss: 10.2127 - y1_output_loss: 4.7298 - y2_output_loss: 5.4828 - y1_output_root_mean_squared_error: 2.1748 - y2_output_root_mean_squared_error: 2.3415 - val_loss: 8.0172 - val_y1_output_loss: 2.3350 - val_y2_output_loss: 5.6822 - val_y1_output_root_mean_squared_error: 1.5281 - val_y2_output_root_mean_squared_error: 2.3837
# Epoch 68/500
# 62/62 [==============================] - 0s 3ms/step - loss: 8.2660 - y1_output_loss: 3.9597 - y2_output_loss: 4.3063 - y1_output_root_mean_squared_error: 1.9899 - y2_output_root_mean_squared_error: 2.0752 - val_loss: 7.3148 - val_y1_output_loss: 3.4792 - val_y2_output_loss: 3.8356 - val_y1_output_root_mean_squared_error: 1.8653 - val_y2_output_root_mean_squared_error: 1.9585
# Epoch 69/500
# 62/62 [==============================] - 0s 3ms/step - loss: 8.4894 - y1_output_loss: 4.0238 - y2_output_loss: 4.4656 - y1_output_root_mean_squared_error: 2.0060 - y2_output_root_mean_squared_error: 2.1132 - val_loss: 6.9476 - val_y1_output_loss: 2.3576 - val_y2_output_loss: 4.5900 - val_y1_output_root_mean_squared_error: 1.5355 - val_y2_output_root_mean_squared_error: 2.1424
# Epoch 70/500
# 62/62 [==============================] - 0s 3ms/step - loss: 8.6703 - y1_output_loss: 4.0940 - y2_output_loss: 4.5763 - y1_output_root_mean_squared_error: 2.0234 - y2_output_root_mean_squared_error: 2.1392 - val_loss: 7.0879 - val_y1_output_loss: 3.3468 - val_y2_output_loss: 3.7411 - val_y1_output_root_mean_squared_error: 1.8294 - val_y2_output_root_mean_squared_error: 1.9342
# Epoch 71/500
# 62/62 [==============================] - 0s 3ms/step - loss: 9.8318 - y1_output_loss: 4.4801 - y2_output_loss: 5.3517 - y1_output_root_mean_squared_error: 2.1166 - y2_output_root_mean_squared_error: 2.3134 - val_loss: 7.8283 - val_y1_output_loss: 2.6959 - val_y2_output_loss: 5.1324 - val_y1_output_root_mean_squared_error: 1.6419 - val_y2_output_root_mean_squared_error: 2.2655
# Epoch 72/500
# 62/62 [==============================] - 0s 3ms/step - loss: 7.9793 - y1_output_loss: 3.8267 - y2_output_loss: 4.1525 - y1_output_root_mean_squared_error: 1.9562 - y2_output_root_mean_squared_error: 2.0378 - val_loss: 8.0787 - val_y1_output_loss: 3.4122 - val_y2_output_loss: 4.6665 - val_y1_output_root_mean_squared_error: 1.8472 - val_y2_output_root_mean_squared_error: 2.1602
# Epoch 73/500
# 62/62 [==============================] - 0s 3ms/step - loss: 9.5229 - y1_output_loss: 4.3255 - y2_output_loss: 5.1974 - y1_output_root_mean_squared_error: 2.0798 - y2_output_root_mean_squared_error: 2.2798 - val_loss: 7.4892 - val_y1_output_loss: 2.4871 - val_y2_output_loss: 5.0021 - val_y1_output_root_mean_squared_error: 1.5771 - val_y2_output_root_mean_squared_error: 2.2365
# Epoch 74/500
# 62/62 [==============================] - 0s 3ms/step - loss: 7.5297 - y1_output_loss: 3.6725 - y2_output_loss: 3.8572 - y1_output_root_mean_squared_error: 1.9164 - y2_output_root_mean_squared_error: 1.9640 - val_loss: 21.4644 - val_y1_output_loss: 5.4972 - val_y2_output_loss: 15.9672 - val_y1_output_root_mean_squared_error: 2.3446 - val_y2_output_root_mean_squared_error: 3.9959
# Epoch 75/500
# 62/62 [==============================] - 0s 3ms/step - loss: 8.5959 - y1_output_loss: 4.0673 - y2_output_loss: 4.5286 - y1_output_root_mean_squared_error: 2.0168 - y2_output_root_mean_squared_error: 2.1281 - val_loss: 12.7323 - val_y1_output_loss: 6.6627 - val_y2_output_loss: 6.0696 - val_y1_output_root_mean_squared_error: 2.5812 - val_y2_output_root_mean_squared_error: 2.4637
# Epoch 76/500
# 62/62 [==============================] - 0s 3ms/step - loss: 8.7614 - y1_output_loss: 4.1357 - y2_output_loss: 4.6257 - y1_output_root_mean_squared_error: 2.0337 - y2_output_root_mean_squared_error: 2.1507 - val_loss: 8.1494 - val_y1_output_loss: 2.5416 - val_y2_output_loss: 5.6079 - val_y1_output_root_mean_squared_error: 1.5942 - val_y2_output_root_mean_squared_error: 2.3681
# Epoch 77/500
# 62/62 [==============================] - 0s 3ms/step - loss: 7.5370 - y1_output_loss: 3.6757 - y2_output_loss: 3.8613 - y1_output_root_mean_squared_error: 1.9172 - y2_output_root_mean_squared_error: 1.9650 - val_loss: 33.9640 - val_y1_output_loss: 8.7980 - val_y2_output_loss: 25.1661 - val_y1_output_root_mean_squared_error: 2.9661 - val_y2_output_root_mean_squared_error: 5.0166
# Epoch 78/500
# 62/62 [==============================] - 0s 3ms/step - loss: 9.4538 - y1_output_loss: 4.3435 - y2_output_loss: 5.1103 - y1_output_root_mean_squared_error: 2.0841 - y2_output_root_mean_squared_error: 2.2606 - val_loss: 7.2143 - val_y1_output_loss: 3.5189 - val_y2_output_loss: 3.6954 - val_y1_output_root_mean_squared_error: 1.8759 - val_y2_output_root_mean_squared_error: 1.9223
# Epoch 79/500
# 62/62 [==============================] - 0s 3ms/step - loss: 7.3983 - y1_output_loss: 3.6023 - y2_output_loss: 3.7960 - y1_output_root_mean_squared_error: 1.8980 - y2_output_root_mean_squared_error: 1.9483 - val_loss: 8.6627 - val_y1_output_loss: 2.1866 - val_y2_output_loss: 6.4761 - val_y1_output_root_mean_squared_error: 1.4787 - val_y2_output_root_mean_squared_error: 2.5448
# Epoch 80/500
# 62/62 [==============================] - 0s 4ms/step - loss: 8.0947 - y1_output_loss: 3.8179 - y2_output_loss: 4.2768 - y1_output_root_mean_squared_error: 1.9539 - y2_output_root_mean_squared_error: 2.0680 - val_loss: 8.0471 - val_y1_output_loss: 2.2064 - val_y2_output_loss: 5.8407 - val_y1_output_root_mean_squared_error: 1.4854 - val_y2_output_root_mean_squared_error: 2.4168
# Epoch 81/500
# 62/62 [==============================] - 0s 3ms/step - loss: 14.1183 - y1_output_loss: 5.8110 - y2_output_loss: 8.3073 - y1_output_root_mean_squared_error: 2.4106 - y2_output_root_mean_squared_error: 2.8822 - val_loss: 6.9577 - val_y1_output_loss: 2.8531 - val_y2_output_loss: 4.1046 - val_y1_output_root_mean_squared_error: 1.6891 - val_y2_output_root_mean_squared_error: 2.0260
# Epoch 82/500
# 62/62 [==============================] - 0s 3ms/step - loss: 7.7331 - y1_output_loss: 3.6935 - y2_output_loss: 4.0396 - y1_output_root_mean_squared_error: 1.9218 - y2_output_root_mean_squared_error: 2.0099 - val_loss: 7.0069 - val_y1_output_loss: 3.7453 - val_y2_output_loss: 3.2616 - val_y1_output_root_mean_squared_error: 1.9353 - val_y2_output_root_mean_squared_error: 1.8060
# Epoch 83/500
# 62/62 [==============================] - 0s 4ms/step - loss: 6.9670 - y1_output_loss: 3.4353 - y2_output_loss: 3.5317 - y1_output_root_mean_squared_error: 1.8535 - y2_output_root_mean_squared_error: 1.8793 - val_loss: 7.9225 - val_y1_output_loss: 1.7918 - val_y2_output_loss: 6.1307 - val_y1_output_root_mean_squared_error: 1.3386 - val_y2_output_root_mean_squared_error: 2.4760
# Epoch 84/500
# 62/62 [==============================] - 0s 3ms/step - loss: 7.6446 - y1_output_loss: 3.6410 - y2_output_loss: 4.0036 - y1_output_root_mean_squared_error: 1.9081 - y2_output_root_mean_squared_error: 2.0009 - val_loss: 6.7578 - val_y1_output_loss: 2.6431 - val_y2_output_loss: 4.1147 - val_y1_output_root_mean_squared_error: 1.6258 - val_y2_output_root_mean_squared_error: 2.0285
# Epoch 85/500
# 62/62 [==============================] - 0s 3ms/step - loss: 7.4437 - y1_output_loss: 3.6017 - y2_output_loss: 3.8420 - y1_output_root_mean_squared_error: 1.8978 - y2_output_root_mean_squared_error: 1.9601 - val_loss: 6.7222 - val_y1_output_loss: 2.5094 - val_y2_output_loss: 4.2129 - val_y1_output_root_mean_squared_error: 1.5841 - val_y2_output_root_mean_squared_error: 2.0525
# Epoch 86/500
# 62/62 [==============================] - 0s 4ms/step - loss: 7.5784 - y1_output_loss: 3.6017 - y2_output_loss: 3.9767 - y1_output_root_mean_squared_error: 1.8978 - y2_output_root_mean_squared_error: 1.9942 - val_loss: 7.2293 - val_y1_output_loss: 3.7411 - val_y2_output_loss: 3.4882 - val_y1_output_root_mean_squared_error: 1.9342 - val_y2_output_root_mean_squared_error: 1.8677
# Epoch 87/500
# 62/62 [==============================] - 0s 3ms/step - loss: 8.2248 - y1_output_loss: 3.8221 - y2_output_loss: 4.4027 - y1_output_root_mean_squared_error: 1.9550 - y2_output_root_mean_squared_error: 2.0983 - val_loss: 9.2390 - val_y1_output_loss: 2.3547 - val_y2_output_loss: 6.8843 - val_y1_output_root_mean_squared_error: 1.5345 - val_y2_output_root_mean_squared_error: 2.6238
# Epoch 88/500
# 62/62 [==============================] - 0s 3ms/step - loss: 6.8312 - y1_output_loss: 3.3467 - y2_output_loss: 3.4845 - y1_output_root_mean_squared_error: 1.8294 - y2_output_root_mean_squared_error: 1.8667 - val_loss: 6.2449 - val_y1_output_loss: 2.4560 - val_y2_output_loss: 3.7889 - val_y1_output_root_mean_squared_error: 1.5672 - val_y2_output_root_mean_squared_error: 1.9465
# Epoch 89/500
# 62/62 [==============================] - 0s 3ms/step - loss: 6.9434 - y1_output_loss: 3.3945 - y2_output_loss: 3.5489 - y1_output_root_mean_squared_error: 1.8424 - y2_output_root_mean_squared_error: 1.8839 - val_loss: 7.9293 - val_y1_output_loss: 2.4402 - val_y2_output_loss: 5.4891 - val_y1_output_root_mean_squared_error: 1.5621 - val_y2_output_root_mean_squared_error: 2.3429
# Epoch 90/500
# 62/62 [==============================] - 0s 3ms/step - loss: 7.0729 - y1_output_loss: 3.4255 - y2_output_loss: 3.6474 - y1_output_root_mean_squared_error: 1.8508 - y2_output_root_mean_squared_error: 1.9098 - val_loss: 8.1248 - val_y1_output_loss: 4.1689 - val_y2_output_loss: 3.9559 - val_y1_output_root_mean_squared_error: 2.0418 - val_y2_output_root_mean_squared_error: 1.9889
# Epoch 91/500
# 62/62 [==============================] - 0s 3ms/step - loss: 7.7275 - y1_output_loss: 3.6513 - y2_output_loss: 4.0762 - y1_output_root_mean_squared_error: 1.9108 - y2_output_root_mean_squared_error: 2.0190 - val_loss: 7.9720 - val_y1_output_loss: 4.2214 - val_y2_output_loss: 3.7506 - val_y1_output_root_mean_squared_error: 2.0546 - val_y2_output_root_mean_squared_error: 1.9366
# Epoch 92/500
# 62/62 [==============================] - 0s 3ms/step - loss: 7.0571 - y1_output_loss: 3.4013 - y2_output_loss: 3.6557 - y1_output_root_mean_squared_error: 1.8443 - y2_output_root_mean_squared_error: 1.9120 - val_loss: 8.4066 - val_y1_output_loss: 2.6521 - val_y2_output_loss: 5.7545 - val_y1_output_root_mean_squared_error: 1.6285 - val_y2_output_root_mean_squared_error: 2.3989
# Epoch 93/500
# 62/62 [==============================] - 0s 3ms/step - loss: 7.2197 - y1_output_loss: 3.4904 - y2_output_loss: 3.7293 - y1_output_root_mean_squared_error: 1.8683 - y2_output_root_mean_squared_error: 1.9311 - val_loss: 9.7357 - val_y1_output_loss: 1.7843 - val_y2_output_loss: 7.9515 - val_y1_output_root_mean_squared_error: 1.3358 - val_y2_output_root_mean_squared_error: 2.8198
# Epoch 94/500
# 62/62 [==============================] - 0s 3ms/step - loss: 8.7350 - y1_output_loss: 4.0179 - y2_output_loss: 4.7171 - y1_output_root_mean_squared_error: 2.0045 - y2_output_root_mean_squared_error: 2.1719 - val_loss: 6.6178 - val_y1_output_loss: 2.1248 - val_y2_output_loss: 4.4929 - val_y1_output_root_mean_squared_error: 1.4577 - val_y2_output_root_mean_squared_error: 2.1197
# Epoch 95/500
# 62/62 [==============================] - 0s 3ms/step - loss: 6.9664 - y1_output_loss: 3.3625 - y2_output_loss: 3.6040 - y1_output_root_mean_squared_error: 1.8337 - y2_output_root_mean_squared_error: 1.8984 - val_loss: 7.5690 - val_y1_output_loss: 1.3427 - val_y2_output_loss: 6.2263 - val_y1_output_root_mean_squared_error: 1.1588 - val_y2_output_root_mean_squared_error: 2.4953
# Epoch 96/500
# 62/62 [==============================] - 0s 3ms/step - loss: 8.0087 - y1_output_loss: 3.6786 - y2_output_loss: 4.3300 - y1_output_root_mean_squared_error: 1.9180 - y2_output_root_mean_squared_error: 2.0809 - val_loss: 7.6262 - val_y1_output_loss: 3.6438 - val_y2_output_loss: 3.9825 - val_y1_output_root_mean_squared_error: 1.9089 - val_y2_output_root_mean_squared_error: 1.9956
# Epoch 97/500
# 62/62 [==============================] - 0s 3ms/step - loss: 6.5868 - y1_output_loss: 3.2281 - y2_output_loss: 3.3588 - y1_output_root_mean_squared_error: 1.7967 - y2_output_root_mean_squared_error: 1.8327 - val_loss: 6.8231 - val_y1_output_loss: 2.2922 - val_y2_output_loss: 4.5310 - val_y1_output_root_mean_squared_error: 1.5140 - val_y2_output_root_mean_squared_error: 2.1286
# Epoch 98/500
# 62/62 [==============================] - 0s 3ms/step - loss: 6.8503 - y1_output_loss: 3.3358 - y2_output_loss: 3.5145 - y1_output_root_mean_squared_error: 1.8264 - y2_output_root_mean_squared_error: 1.8747 - val_loss: 6.5817 - val_y1_output_loss: 2.9264 - val_y2_output_loss: 3.6552 - val_y1_output_root_mean_squared_error: 1.7107 - val_y2_output_root_mean_squared_error: 1.9119
# Epoch 99/500
# 62/62 [==============================] - 0s 3ms/step - loss: 7.5461 - y1_output_loss: 3.5602 - y2_output_loss: 3.9858 - y1_output_root_mean_squared_error: 1.8869 - y2_output_root_mean_squared_error: 1.9965 - val_loss: 6.9424 - val_y1_output_loss: 3.5913 - val_y2_output_loss: 3.3511 - val_y1_output_root_mean_squared_error: 1.8951 - val_y2_output_root_mean_squared_error: 1.8306
# Epoch 100/500
# 62/62 [==============================] - 0s 3ms/step - loss: 9.4229 - y1_output_loss: 4.2627 - y2_output_loss: 5.1602 - y1_output_root_mean_squared_error: 2.0646 - y2_output_root_mean_squared_error: 2.2716 - val_loss: 6.3724 - val_y1_output_loss: 2.9249 - val_y2_output_loss: 3.4475 - val_y1_output_root_mean_squared_error: 1.7102 - val_y2_output_root_mean_squared_error: 1.8568
# Epoch 101/500
# 62/62 [==============================] - 0s 3ms/step - loss: 7.1909 - y1_output_loss: 3.4431 - y2_output_loss: 3.7479 - y1_output_root_mean_squared_error: 1.8555 - y2_output_root_mean_squared_error: 1.9359 - val_loss: 7.0180 - val_y1_output_loss: 2.0169 - val_y2_output_loss: 5.0011 - val_y1_output_root_mean_squared_error: 1.4202 - val_y2_output_root_mean_squared_error: 2.2363
# Epoch 102/500
# 62/62 [==============================] - 0s 3ms/step - loss: 7.1122 - y1_output_loss: 3.4110 - y2_output_loss: 3.7012 - y1_output_root_mean_squared_error: 1.8469 - y2_output_root_mean_squared_error: 1.9239 - val_loss: 6.9621 - val_y1_output_loss: 3.4488 - val_y2_output_loss: 3.5133 - val_y1_output_root_mean_squared_error: 1.8571 - val_y2_output_root_mean_squared_error: 1.8744
# Epoch 103/500
# 62/62 [==============================] - 0s 3ms/step - loss: 6.5372 - y1_output_loss: 3.2056 - y2_output_loss: 3.3316 - y1_output_root_mean_squared_error: 1.7904 - y2_output_root_mean_squared_error: 1.8253 - val_loss: 7.1124 - val_y1_output_loss: 1.9776 - val_y2_output_loss: 5.1348 - val_y1_output_root_mean_squared_error: 1.4063 - val_y2_output_root_mean_squared_error: 2.2660
# Epoch 104/500
# 62/62 [==============================] - 0s 3ms/step - loss: 6.3438 - y1_output_loss: 3.1109 - y2_output_loss: 3.2328 - y1_output_root_mean_squared_error: 1.7638 - y2_output_root_mean_squared_error: 1.7980 - val_loss: 6.5021 - val_y1_output_loss: 3.2257 - val_y2_output_loss: 3.2764 - val_y1_output_root_mean_squared_error: 1.7960 - val_y2_output_root_mean_squared_error: 1.8101
# Epoch 105/500
# 62/62 [==============================] - 0s 3ms/step - loss: 6.5109 - y1_output_loss: 3.1975 - y2_output_loss: 3.3134 - y1_output_root_mean_squared_error: 1.7881 - y2_output_root_mean_squared_error: 1.8203 - val_loss: 6.5691 - val_y1_output_loss: 3.1392 - val_y2_output_loss: 3.4299 - val_y1_output_root_mean_squared_error: 1.7718 - val_y2_output_root_mean_squared_error: 1.8520
# Epoch 106/500
# 62/62 [==============================] - 0s 3ms/step - loss: 6.5519 - y1_output_loss: 3.1903 - y2_output_loss: 3.3615 - y1_output_root_mean_squared_error: 1.7861 - y2_output_root_mean_squared_error: 1.8334 - val_loss: 7.5262 - val_y1_output_loss: 1.9941 - val_y2_output_loss: 5.5321 - val_y1_output_root_mean_squared_error: 1.4121 - val_y2_output_root_mean_squared_error: 2.3520
# Epoch 107/500
# 62/62 [==============================] - 0s 3ms/step - loss: 7.6086 - y1_output_loss: 3.5562 - y2_output_loss: 4.0523 - y1_output_root_mean_squared_error: 1.8858 - y2_output_root_mean_squared_error: 2.0130 - val_loss: 6.4338 - val_y1_output_loss: 2.3235 - val_y2_output_loss: 4.1103 - val_y1_output_root_mean_squared_error: 1.5243 - val_y2_output_root_mean_squared_error: 2.0274
# Epoch 108/500
# 62/62 [==============================] - 0s 3ms/step - loss: 6.4108 - y1_output_loss: 3.1501 - y2_output_loss: 3.2606 - y1_output_root_mean_squared_error: 1.7749 - y2_output_root_mean_squared_error: 1.8057 - val_loss: 6.7227 - val_y1_output_loss: 2.3907 - val_y2_output_loss: 4.3319 - val_y1_output_root_mean_squared_error: 1.5462 - val_y2_output_root_mean_squared_error: 2.0813
# Epoch 109/500
# 62/62 [==============================] - 0s 3ms/step - loss: 6.4407 - y1_output_loss: 3.1506 - y2_output_loss: 3.2901 - y1_output_root_mean_squared_error: 1.7750 - y2_output_root_mean_squared_error: 1.8139 - val_loss: 5.9649 - val_y1_output_loss: 2.0779 - val_y2_output_loss: 3.8870 - val_y1_output_root_mean_squared_error: 1.4415 - val_y2_output_root_mean_squared_error: 1.9715
# Epoch 110/500
# 62/62 [==============================] - 0s 3ms/step - loss: 8.3539 - y1_output_loss: 3.8235 - y2_output_loss: 4.5304 - y1_output_root_mean_squared_error: 1.9554 - y2_output_root_mean_squared_error: 2.1285 - val_loss: 8.5343 - val_y1_output_loss: 5.2074 - val_y2_output_loss: 3.3269 - val_y1_output_root_mean_squared_error: 2.2820 - val_y2_output_root_mean_squared_error: 1.8240
# Epoch 111/500
# 62/62 [==============================] - 0s 3ms/step - loss: 6.5812 - y1_output_loss: 3.2091 - y2_output_loss: 3.3721 - y1_output_root_mean_squared_error: 1.7914 - y2_output_root_mean_squared_error: 1.8363 - val_loss: 6.4898 - val_y1_output_loss: 2.7317 - val_y2_output_loss: 3.7581 - val_y1_output_root_mean_squared_error: 1.6528 - val_y2_output_root_mean_squared_error: 1.9386
# Epoch 112/500
# 62/62 [==============================] - 0s 3ms/step - loss: 6.3461 - y1_output_loss: 3.1209 - y2_output_loss: 3.2253 - y1_output_root_mean_squared_error: 1.7666 - y2_output_root_mean_squared_error: 1.7959 - val_loss: 6.4410 - val_y1_output_loss: 2.6453 - val_y2_output_loss: 3.7957 - val_y1_output_root_mean_squared_error: 1.6264 - val_y2_output_root_mean_squared_error: 1.9483
# Epoch 113/500
# 62/62 [==============================] - 0s 4ms/step - loss: 7.2151 - y1_output_loss: 3.4212 - y2_output_loss: 3.7939 - y1_output_root_mean_squared_error: 1.8497 - y2_output_root_mean_squared_error: 1.9478 - val_loss: 9.0237 - val_y1_output_loss: 4.6422 - val_y2_output_loss: 4.3814 - val_y1_output_root_mean_squared_error: 2.1546 - val_y2_output_root_mean_squared_error: 2.0932
# Epoch 114/500
# 62/62 [==============================] - 0s 4ms/step - loss: 6.5073 - y1_output_loss: 3.1824 - y2_output_loss: 3.3249 - y1_output_root_mean_squared_error: 1.7839 - y2_output_root_mean_squared_error: 1.8234 - val_loss: 6.9624 - val_y1_output_loss: 3.6711 - val_y2_output_loss: 3.2914 - val_y1_output_root_mean_squared_error: 1.9160 - val_y2_output_root_mean_squared_error: 1.8142
# Epoch 115/500
# 62/62 [==============================] - 0s 3ms/step - loss: 6.5900 - y1_output_loss: 3.2107 - y2_output_loss: 3.3793 - y1_output_root_mean_squared_error: 1.7918 - y2_output_root_mean_squared_error: 1.8383 - val_loss: 5.8535 - val_y1_output_loss: 2.8121 - val_y2_output_loss: 3.0414 - val_y1_output_root_mean_squared_error: 1.6769 - val_y2_output_root_mean_squared_error: 1.7440
# Epoch 116/500
# 62/62 [==============================] - 0s 3ms/step - loss: 6.8613 - y1_output_loss: 3.3020 - y2_output_loss: 3.5592 - y1_output_root_mean_squared_error: 1.8171 - y2_output_root_mean_squared_error: 1.8866 - val_loss: 6.4725 - val_y1_output_loss: 3.4616 - val_y2_output_loss: 3.0109 - val_y1_output_root_mean_squared_error: 1.8605 - val_y2_output_root_mean_squared_error: 1.7352
# Epoch 117/500
# 62/62 [==============================] - 0s 3ms/step - loss: 10.3318 - y1_output_loss: 4.6708 - y2_output_loss: 5.6610 - y1_output_root_mean_squared_error: 2.1612 - y2_output_root_mean_squared_error: 2.3793 - val_loss: 6.4503 - val_y1_output_loss: 2.5224 - val_y2_output_loss: 3.9279 - val_y1_output_root_mean_squared_error: 1.5882 - val_y2_output_root_mean_squared_error: 1.9819
# Epoch 118/500
# 62/62 [==============================] - 0s 4ms/step - loss: 6.4249 - y1_output_loss: 3.1379 - y2_output_loss: 3.2871 - y1_output_root_mean_squared_error: 1.7714 - y2_output_root_mean_squared_error: 1.8130 - val_loss: 6.1884 - val_y1_output_loss: 2.0606 - val_y2_output_loss: 4.1279 - val_y1_output_root_mean_squared_error: 1.4355 - val_y2_output_root_mean_squared_error: 2.0317
# Epoch 119/500
# 62/62 [==============================] - 0s 3ms/step - loss: 6.3155 - y1_output_loss: 3.0937 - y2_output_loss: 3.2218 - y1_output_root_mean_squared_error: 1.7589 - y2_output_root_mean_squared_error: 1.7949 - val_loss: 6.4782 - val_y1_output_loss: 3.1142 - val_y2_output_loss: 3.3640 - val_y1_output_root_mean_squared_error: 1.7647 - val_y2_output_root_mean_squared_error: 1.8341
# Epoch 120/500
# 62/62 [==============================] - 0s 3ms/step - loss: 6.7565 - y1_output_loss: 3.2640 - y2_output_loss: 3.4925 - y1_output_root_mean_squared_error: 1.8067 - y2_output_root_mean_squared_error: 1.8688 - val_loss: 6.5839 - val_y1_output_loss: 1.9162 - val_y2_output_loss: 4.6678 - val_y1_output_root_mean_squared_error: 1.3843 - val_y2_output_root_mean_squared_error: 2.1605
# Epoch 121/500
# 62/62 [==============================] - 0s 3ms/step - loss: 6.2525 - y1_output_loss: 3.0840 - y2_output_loss: 3.1685 - y1_output_root_mean_squared_error: 1.7561 - y2_output_root_mean_squared_error: 1.7800 - val_loss: 7.1924 - val_y1_output_loss: 3.9433 - val_y2_output_loss: 3.2491 - val_y1_output_root_mean_squared_error: 1.9858 - val_y2_output_root_mean_squared_error: 1.8025
# Epoch 122/500
# ...
# Epoch 461/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.6135 - y1_output_loss: 2.7828 - y2_output_loss: 2.8306 - y1_output_root_mean_squared_error: 1.6682 - y2_output_root_mean_squared_error: 1.6824 - val_loss: 6.0722 - val_y1_output_loss: 2.8344 - val_y2_output_loss: 3.2378 - val_y1_output_root_mean_squared_error: 1.6836 - val_y2_output_root_mean_squared_error: 1.7994
# Epoch 462/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.7426 - y1_output_loss: 2.8221 - y2_output_loss: 2.9204 - y1_output_root_mean_squared_error: 1.6799 - y2_output_root_mean_squared_error: 1.7089 - val_loss: 5.8340 - val_y1_output_loss: 2.8840 - val_y2_output_loss: 2.9500 - val_y1_output_root_mean_squared_error: 1.6982 - val_y2_output_root_mean_squared_error: 1.7176
# Epoch 463/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.5500 - y1_output_loss: 2.7597 - y2_output_loss: 2.7902 - y1_output_root_mean_squared_error: 1.6612 - y2_output_root_mean_squared_error: 1.6704 - val_loss: 5.9185 - val_y1_output_loss: 2.5089 - val_y2_output_loss: 3.4096 - val_y1_output_root_mean_squared_error: 1.5840 - val_y2_output_root_mean_squared_error: 1.8465
# Epoch 464/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.5755 - y1_output_loss: 2.7676 - y2_output_loss: 2.8079 - y1_output_root_mean_squared_error: 1.6636 - y2_output_root_mean_squared_error: 1.6757 - val_loss: 5.8870 - val_y1_output_loss: 2.7083 - val_y2_output_loss: 3.1787 - val_y1_output_root_mean_squared_error: 1.6457 - val_y2_output_root_mean_squared_error: 1.7829
# Epoch 465/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.5524 - y1_output_loss: 2.7573 - y2_output_loss: 2.7951 - y1_output_root_mean_squared_error: 1.6605 - y2_output_root_mean_squared_error: 1.6719 - val_loss: 5.8489 - val_y1_output_loss: 2.4264 - val_y2_output_loss: 3.4224 - val_y1_output_root_mean_squared_error: 1.5577 - val_y2_output_root_mean_squared_error: 1.8500
# Epoch 466/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.5799 - y1_output_loss: 2.7713 - y2_output_loss: 2.8086 - y1_output_root_mean_squared_error: 1.6647 - y2_output_root_mean_squared_error: 1.6759 - val_loss: 6.1087 - val_y1_output_loss: 2.9282 - val_y2_output_loss: 3.1805 - val_y1_output_root_mean_squared_error: 1.7112 - val_y2_output_root_mean_squared_error: 1.7834
# Epoch 467/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.5717 - y1_output_loss: 2.7701 - y2_output_loss: 2.8016 - y1_output_root_mean_squared_error: 1.6644 - y2_output_root_mean_squared_error: 1.6738 - val_loss: 5.7021 - val_y1_output_loss: 2.2991 - val_y2_output_loss: 3.4031 - val_y1_output_root_mean_squared_error: 1.5163 - val_y2_output_root_mean_squared_error: 1.8447
# Epoch 468/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.4392 - y1_output_loss: 2.7200 - y2_output_loss: 2.7192 - y1_output_root_mean_squared_error: 1.6493 - y2_output_root_mean_squared_error: 1.6490 - val_loss: 5.8671 - val_y1_output_loss: 2.9867 - val_y2_output_loss: 2.8804 - val_y1_output_root_mean_squared_error: 1.7282 - val_y2_output_root_mean_squared_error: 1.6972
# Epoch 469/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.5327 - y1_output_loss: 2.7535 - y2_output_loss: 2.7791 - y1_output_root_mean_squared_error: 1.6594 - y2_output_root_mean_squared_error: 1.6671 - val_loss: 5.8169 - val_y1_output_loss: 2.5268 - val_y2_output_loss: 3.2901 - val_y1_output_root_mean_squared_error: 1.5896 - val_y2_output_root_mean_squared_error: 1.8139
# Epoch 470/500
# 62/62 [==============================] - 0s 3ms/step - loss: 5.7286 - y1_output_loss: 2.8170 - y2_output_loss: 2.9115 - y1_output_root_mean_squared_error: 1.6784 - y2_output_root_mean_squared_error: 1.7063 - val_loss: 5.8898 - val_y1_output_loss: 2.9066 - val_y2_output_loss: 2.9831 - val_y1_output_root_mean_squared_error: 1.7049 - val_y2_output_root_mean_squared_error: 1.7272
# Epoch 471/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.5448 - y1_output_loss: 2.7612 - y2_output_loss: 2.7836 - y1_output_root_mean_squared_error: 1.6617 - y2_output_root_mean_squared_error: 1.6684 - val_loss: 6.1658 - val_y1_output_loss: 3.1928 - val_y2_output_loss: 2.9730 - val_y1_output_root_mean_squared_error: 1.7868 - val_y2_output_root_mean_squared_error: 1.7242
# Epoch 472/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.5469 - y1_output_loss: 2.7548 - y2_output_loss: 2.7920 - y1_output_root_mean_squared_error: 1.6598 - y2_output_root_mean_squared_error: 1.6709 - val_loss: 5.8933 - val_y1_output_loss: 2.8897 - val_y2_output_loss: 3.0036 - val_y1_output_root_mean_squared_error: 1.6999 - val_y2_output_root_mean_squared_error: 1.7331
# Epoch 473/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.5507 - y1_output_loss: 2.7586 - y2_output_loss: 2.7921 - y1_output_root_mean_squared_error: 1.6609 - y2_output_root_mean_squared_error: 1.6710 - val_loss: 5.7870 - val_y1_output_loss: 2.4571 - val_y2_output_loss: 3.3298 - val_y1_output_root_mean_squared_error: 1.5675 - val_y2_output_root_mean_squared_error: 1.8248
# Epoch 474/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.4893 - y1_output_loss: 2.7355 - y2_output_loss: 2.7538 - y1_output_root_mean_squared_error: 1.6539 - y2_output_root_mean_squared_error: 1.6595 - val_loss: 5.9275 - val_y1_output_loss: 2.5625 - val_y2_output_loss: 3.3650 - val_y1_output_root_mean_squared_error: 1.6008 - val_y2_output_root_mean_squared_error: 1.8344
# Epoch 475/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.5646 - y1_output_loss: 2.7649 - y2_output_loss: 2.7996 - y1_output_root_mean_squared_error: 1.6628 - y2_output_root_mean_squared_error: 1.6732 - val_loss: 11.3154 - val_y1_output_loss: 6.8261 - val_y2_output_loss: 4.4893 - val_y1_output_root_mean_squared_error: 2.6127 - val_y2_output_root_mean_squared_error: 2.1188
# Epoch 476/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.6525 - y1_output_loss: 2.7977 - y2_output_loss: 2.8548 - y1_output_root_mean_squared_error: 1.6726 - y2_output_root_mean_squared_error: 1.6896 - val_loss: 5.8265 - val_y1_output_loss: 2.4637 - val_y2_output_loss: 3.3629 - val_y1_output_root_mean_squared_error: 1.5696 - val_y2_output_root_mean_squared_error: 1.8338
# Epoch 477/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.5685 - y1_output_loss: 2.7623 - y2_output_loss: 2.8062 - y1_output_root_mean_squared_error: 1.6620 - y2_output_root_mean_squared_error: 1.6752 - val_loss: 5.8911 - val_y1_output_loss: 2.4027 - val_y2_output_loss: 3.4884 - val_y1_output_root_mean_squared_error: 1.5501 - val_y2_output_root_mean_squared_error: 1.8677
# Epoch 478/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.5639 - y1_output_loss: 2.7598 - y2_output_loss: 2.8040 - y1_output_root_mean_squared_error: 1.6613 - y2_output_root_mean_squared_error: 1.6745 - val_loss: 5.8388 - val_y1_output_loss: 2.7234 - val_y2_output_loss: 3.1153 - val_y1_output_root_mean_squared_error: 1.6503 - val_y2_output_root_mean_squared_error: 1.7650
# Epoch 479/500
# 62/62 [==============================] - 0s 3ms/step - loss: 5.5323 - y1_output_loss: 2.7538 - y2_output_loss: 2.7785 - y1_output_root_mean_squared_error: 1.6595 - y2_output_root_mean_squared_error: 1.6669 - val_loss: 6.0058 - val_y1_output_loss: 2.5367 - val_y2_output_loss: 3.4691 - val_y1_output_root_mean_squared_error: 1.5927 - val_y2_output_root_mean_squared_error: 1.8625
# Epoch 480/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.5644 - y1_output_loss: 2.7636 - y2_output_loss: 2.8007 - y1_output_root_mean_squared_error: 1.6624 - y2_output_root_mean_squared_error: 1.6735 - val_loss: 6.3542 - val_y1_output_loss: 2.0040 - val_y2_output_loss: 4.3502 - val_y1_output_root_mean_squared_error: 1.4156 - val_y2_output_root_mean_squared_error: 2.0857
# Epoch 481/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.4713 - y1_output_loss: 2.7304 - y2_output_loss: 2.7410 - y1_output_root_mean_squared_error: 1.6524 - y2_output_root_mean_squared_error: 1.6556 - val_loss: 5.8946 - val_y1_output_loss: 2.3494 - val_y2_output_loss: 3.5451 - val_y1_output_root_mean_squared_error: 1.5328 - val_y2_output_root_mean_squared_error: 1.8829
# Epoch 482/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.6426 - y1_output_loss: 2.7887 - y2_output_loss: 2.8539 - y1_output_root_mean_squared_error: 1.6700 - y2_output_root_mean_squared_error: 1.6893 - val_loss: 5.8692 - val_y1_output_loss: 2.7761 - val_y2_output_loss: 3.0931 - val_y1_output_root_mean_squared_error: 1.6662 - val_y2_output_root_mean_squared_error: 1.7587
# Epoch 483/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.5831 - y1_output_loss: 2.7718 - y2_output_loss: 2.8114 - y1_output_root_mean_squared_error: 1.6649 - y2_output_root_mean_squared_error: 1.6767 - val_loss: 5.7685 - val_y1_output_loss: 2.8041 - val_y2_output_loss: 2.9645 - val_y1_output_root_mean_squared_error: 1.6745 - val_y2_output_root_mean_squared_error: 1.7218
# Epoch 484/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.5262 - y1_output_loss: 2.7507 - y2_output_loss: 2.7755 - y1_output_root_mean_squared_error: 1.6585 - y2_output_root_mean_squared_error: 1.6660 - val_loss: 5.8640 - val_y1_output_loss: 2.8558 - val_y2_output_loss: 3.0082 - val_y1_output_root_mean_squared_error: 1.6899 - val_y2_output_root_mean_squared_error: 1.7344
# Epoch 485/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.5297 - y1_output_loss: 2.7501 - y2_output_loss: 2.7797 - y1_output_root_mean_squared_error: 1.6583 - y2_output_root_mean_squared_error: 1.6672 - val_loss: 5.8388 - val_y1_output_loss: 2.2827 - val_y2_output_loss: 3.5561 - val_y1_output_root_mean_squared_error: 1.5109 - val_y2_output_root_mean_squared_error: 1.8858
# Epoch 486/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.6035 - y1_output_loss: 2.7687 - y2_output_loss: 2.8348 - y1_output_root_mean_squared_error: 1.6639 - y2_output_root_mean_squared_error: 1.6837 - val_loss: 5.8525 - val_y1_output_loss: 2.0489 - val_y2_output_loss: 3.8037 - val_y1_output_root_mean_squared_error: 1.4314 - val_y2_output_root_mean_squared_error: 1.9503
# Epoch 487/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.7184 - y1_output_loss: 2.8142 - y2_output_loss: 2.9042 - y1_output_root_mean_squared_error: 1.6776 - y2_output_root_mean_squared_error: 1.7042 - val_loss: 5.9195 - val_y1_output_loss: 2.4448 - val_y2_output_loss: 3.4747 - val_y1_output_root_mean_squared_error: 1.5636 - val_y2_output_root_mean_squared_error: 1.8641
# Epoch 488/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.8426 - y1_output_loss: 2.8545 - y2_output_loss: 2.9880 - y1_output_root_mean_squared_error: 1.6895 - y2_output_root_mean_squared_error: 1.7286 - val_loss: 6.2421 - val_y1_output_loss: 2.4998 - val_y2_output_loss: 3.7423 - val_y1_output_root_mean_squared_error: 1.5811 - val_y2_output_root_mean_squared_error: 1.9345
# Epoch 489/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.8258 - y1_output_loss: 2.8568 - y2_output_loss: 2.9690 - y1_output_root_mean_squared_error: 1.6902 - y2_output_root_mean_squared_error: 1.7231 - val_loss: 6.4949 - val_y1_output_loss: 2.6342 - val_y2_output_loss: 3.8607 - val_y1_output_root_mean_squared_error: 1.6230 - val_y2_output_root_mean_squared_error: 1.9649
# Epoch 490/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.9510 - y1_output_loss: 2.8931 - y2_output_loss: 3.0579 - y1_output_root_mean_squared_error: 1.7009 - y2_output_root_mean_squared_error: 1.7487 - val_loss: 6.2302 - val_y1_output_loss: 2.2582 - val_y2_output_loss: 3.9720 - val_y1_output_root_mean_squared_error: 1.5027 - val_y2_output_root_mean_squared_error: 1.9930
# Epoch 491/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.5793 - y1_output_loss: 2.7711 - y2_output_loss: 2.8082 - y1_output_root_mean_squared_error: 1.6647 - y2_output_root_mean_squared_error: 1.6758 - val_loss: 6.3566 - val_y1_output_loss: 3.4276 - val_y2_output_loss: 2.9290 - val_y1_output_root_mean_squared_error: 1.8514 - val_y2_output_root_mean_squared_error: 1.7114
# Epoch 492/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.5015 - y1_output_loss: 2.7448 - y2_output_loss: 2.7567 - y1_output_root_mean_squared_error: 1.6568 - y2_output_root_mean_squared_error: 1.6603 - val_loss: 6.9039 - val_y1_output_loss: 3.8786 - val_y2_output_loss: 3.0253 - val_y1_output_root_mean_squared_error: 1.9694 - val_y2_output_root_mean_squared_error: 1.7393
# Epoch 493/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.5100 - y1_output_loss: 2.7412 - y2_output_loss: 2.7688 - y1_output_root_mean_squared_error: 1.6557 - y2_output_root_mean_squared_error: 1.6640 - val_loss: 5.8769 - val_y1_output_loss: 2.8462 - val_y2_output_loss: 3.0307 - val_y1_output_root_mean_squared_error: 1.6871 - val_y2_output_root_mean_squared_error: 1.7409
# Epoch 494/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.7700 - y1_output_loss: 2.8371 - y2_output_loss: 2.9329 - y1_output_root_mean_squared_error: 1.6844 - y2_output_root_mean_squared_error: 1.7126 - val_loss: 7.3345 - val_y1_output_loss: 2.0138 - val_y2_output_loss: 5.3207 - val_y1_output_root_mean_squared_error: 1.4191 - val_y2_output_root_mean_squared_error: 2.3067
# Epoch 495/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.5321 - y1_output_loss: 2.7568 - y2_output_loss: 2.7754 - y1_output_root_mean_squared_error: 1.6604 - y2_output_root_mean_squared_error: 1.6659 - val_loss: 6.5077 - val_y1_output_loss: 1.7826 - val_y2_output_loss: 4.7251 - val_y1_output_root_mean_squared_error: 1.3351 - val_y2_output_root_mean_squared_error: 2.1737
# Epoch 496/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.5320 - y1_output_loss: 2.7472 - y2_output_loss: 2.7848 - y1_output_root_mean_squared_error: 1.6575 - y2_output_root_mean_squared_error: 1.6688 - val_loss: 5.9636 - val_y1_output_loss: 2.4215 - val_y2_output_loss: 3.5421 - val_y1_output_root_mean_squared_error: 1.5561 - val_y2_output_root_mean_squared_error: 1.8821
# Epoch 497/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.6195 - y1_output_loss: 2.7765 - y2_output_loss: 2.8430 - y1_output_root_mean_squared_error: 1.6663 - y2_output_root_mean_squared_error: 1.6861 - val_loss: 5.8173 - val_y1_output_loss: 2.6598 - val_y2_output_loss: 3.1576 - val_y1_output_root_mean_squared_error: 1.6309 - val_y2_output_root_mean_squared_error: 1.7770
# Epoch 498/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.4820 - y1_output_loss: 2.7336 - y2_output_loss: 2.7484 - y1_output_root_mean_squared_error: 1.6534 - y2_output_root_mean_squared_error: 1.6578 - val_loss: 5.9485 - val_y1_output_loss: 2.4565 - val_y2_output_loss: 3.4920 - val_y1_output_root_mean_squared_error: 1.5673 - val_y2_output_root_mean_squared_error: 1.8687
# Epoch 499/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.4632 - y1_output_loss: 2.7247 - y2_output_loss: 2.7385 - y1_output_root_mean_squared_error: 1.6507 - y2_output_root_mean_squared_error: 1.6548 - val_loss: 5.8316 - val_y1_output_loss: 2.3786 - val_y2_output_loss: 3.4529 - val_y1_output_root_mean_squared_error: 1.5423 - val_y2_output_root_mean_squared_error: 1.8582
# Epoch 500/500
# 62/62 [==============================] - 0s 4ms/step - loss: 5.4934 - y1_output_loss: 2.7371 - y2_output_loss: 2.7563 - y1_output_root_mean_squared_error: 1.6544 - y2_output_root_mean_squared_error: 1.6602 - val_loss: 6.0626 - val_y1_output_loss: 2.9252 - val_y2_output_loss: 3.1374 - val_y1_output_root_mean_squared_error: 1.7103 - val_y2_output_root_mean_squared_error: 1.7713

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 5/5 [==============================] - 0s 3ms/step - loss: 6.0626 - y1_output_loss: 2.9252 - y2_output_loss: 3.1374 - y1_output_root_mean_squared_error: 1.7103 - y2_output_root_mean_squared_error: 1.7713
# Loss = 6.062577724456787, Y1_loss = 2.925175189971924, Y1_mse = 1.710314393043518, Y2_loss = 3.1374025344848633, Y2_mse = 1.7712714672088623

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss']);
plt.plot(history.history['y1_output_loss']);
plt.plot(history.history['y2_output_loss']);

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'y1_output_loss', 'y2_output_loss', 'y1_output_root_mean_squared_error', 'y2_output_root_mean_squared_error', 'val_loss', 'val_y1_output_loss', 'val_y2_output_loss', 'val_y1_output_root_mean_squared_error', 'val_y2_output_root_mean_squared_error'])

# %% [markdown]
# # Siamese network
#
# It's a sub model that recieves multiple inputs, and uses the same weights for all of them, in the image below, you can see two identical parts of the model, marked as having shared weights, in code we use one network and simply pass the two inputs through it.
# ![Siamese network example](../images/Siamese-network-example.png)

# %%
from tensorflow.keras.layers import Flatten, Dropout, Lambda
import tensorflow.keras.backend as K

# %%
# construct a Siamese network with shared weights
# The input is 28x28 images.
# The output is a vector of size 128.
def siamese_network(prefex=''):
  xs = Input((28, 28), name=prefex+'input')
  x = Flatten(name=prefex+'_Flatten')(xs)
  x = Dense(128, activation='relu', name=prefex+'_D1')(x)
  x = Dropout(0.1, name=prefex+'_D1_dropout')(x)
  x = Dense(128, activation='relu', name=prefex+'_D2')(x)
  x = Dropout(0.1, name=prefex+'_D2_dropout')(x)
  x = Dense(128, activation='relu', name=prefex+'_D3')(x)
  return tf.keras.Model(inputs=[xs], outputs=[x])

# %%
# Construct the model that uses the Siamese network
# create two inputs for the siamese network
left_input = Input((28, 28), name='left_input')
right_input = Input((28, 28), name='right_input')

# create the siamese network
siamese_net = siamese_network('siamese_')

# create the outputs of the siamese network
left_output = siamese_net(left_input)
right_output = siamese_net(right_input)

# %%
# define euclidean distance function
def euclidean_distance(vects):
  x, y = vects
  return K.sqrt(K.maximum(K.sum(K.square(x - y), axis=1, keepdims=True), K.epsilon()))

def eucl_dist_output_shape(shapes):
  shape1, shape2 = shapes
  return (shape1[0], 1)

# %%
# merge the outputs of the siamese network with euclidean distance
euclidean_distance = Lambda(euclidean_distance, output_shape=eucl_dist_output_shape)([left_output, right_output])

# and create the final model
model = tf.keras.Model(inputs=[left_input, right_input], outputs=[euclidean_distance])

# %%
# show Siamese network architecture and summary
print(siamese_net.summary())
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# siamese_input (InputLayer)   [(None, 28, 28)]          0
# _________________________________________________________________
# siamese__Flatten (Flatten)   (None, 784)               0
# _________________________________________________________________
# siamese__D1 (Dense)          (None, 128)               100480
# _________________________________________________________________
# siamese__D1_dropout (Dropout (None, 128)               0
# _________________________________________________________________
# siamese__D2 (Dense)          (None, 128)               16512
# _________________________________________________________________
# siamese__D2_dropout (Dropout (None, 128)               0
# _________________________________________________________________
# siamese__D3 (Dense)          (None, 128)               16512
# =================================================================
# Total params: 133,504
# Trainable params: 133,504
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# show the model architecture
print(model.summary())
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='model.png', show_shapes=True)
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# left_input (InputLayer)         [(None, 28, 28)]     0
# __________________________________________________________________________________________________
# right_input (InputLayer)        [(None, 28, 28)]     0
# __________________________________________________________________________________________________
# model_2 (Functional)            (None, 128)          133504      left_input[0][0]
#                                                                  right_input[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 1)            0           model_2[0][0]
#                                                                  model_2[1][0]
# ==================================================================================================
# Total params: 133,504
# Trainable params: 133,504
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.001)

# %%
# Contrastive loss function (we will address this in a future post)
def contrastive_loss_with_margin(margin):
  def contrastive_loss(y_true, y_pred):
    '''Contrastive loss from Hadsell-et-al.'06
    http://yann.lecun.com/exdb/publis/pdf/hadsell-chopra-lecun-06.pdf
    '''
    square_pred = K.square(y_pred)
    margin_square = K.square(K.maximum(margin - y_pred, 0))
    return K.mean(y_true * square_pred + (1 - y_true) * margin_square)
  return contrastive_loss

# %%
# Compile the model
model.compile(
  optimizer=optimizer,
  loss=[contrastive_loss_with_margin(margin=1.0)]
)

# %% [markdown]
# # Shall we load the data?
#
# The data we will work with is the Fashion MNIST dataset, which is a dataset of 60,000 grayscale images of size 28x28 pixels.
#
# The model we are trying to build should output the distance between the images, namely a pair of images from Fashion MNIST dataset; so we need to reformat the images into pairs with a label of 1 if they are from the same class and 0 otherwise.
#
# we want the data in the format
#
# image_1 | image_2 | label
# --------|---------|--------
# 0.png   | 1.png   | 1
# 0.png   | 2.png   | 0
#  ....   | ....    | ....

# %%
# load the dataset
from tensorflow.keras.datasets import fashion_mnist

(train_X, train_y), (test_X, test_y) = fashion_mnist.load_data()

# %%
# Some preprocessing
def preprocess(x):
  x = x.reshape(x.shape[0], 28, 28).astype('float32')
  x /= 255
  return x

# %%
train_X = preprocess(train_X)
test_X = preprocess(test_X)

# %% [markdown]
# # Making pairs
#
# Splitting the dataset into pairs should be an easy two nested loops, or may be you can do it easier, but anyway, this will give us more data than we need, and will be too time consuming, instead we will try to limit the number of pairs we have by some restrictions:
#
# 1. if N is the size of smallest class, then we can have 2(N - 1) pairs for each class.
# 2. Half of the pairs per class should be of the same class, hence will be labeled as 1 `match`.
# 3. the other half of pairs will be made of one image of current class, and another from another randomly selected class, hence will be labeled as 0 `mismatch`.

# %%
# reformat the data into pairs of images
def reformat(images, labels):
  # get size of smallest class
  min_class_size = min(np.bincount(labels)) - 1
  print(min_class_size)
  pairs = []            # list of image pairs
  areMatching = []      # list of match/missMatch labels

  class_indices = [np.where(labels == i)[0] for i in range(10)]
    
  for cur_class in range(10):
    for i in range(min_class_size):
      # the current image index is the ith image within the current class
      cur_image_index = class_indices[cur_class][i]
      # and the matching image is the one after it within the same class
      matching_image_index = class_indices[cur_class][i + 1]

      # add matching pairs
      cur_image = images[cur_image_index]
      matching_image = images[matching_image_index]

      pairs.append([cur_image, matching_image])
      areMatching.append(1)

      # add non-matching images
      random_class = np.random.randint(0, 9)

      # random image index is the ith image within the random class, so that the result is deterministic
      random_image_index = class_indices[random_class][i]
      non_matching_image = images[random_image_index]

      pairs.append([cur_image, non_matching_image])
      areMatching.append(0)
  
  return np.array(pairs), np.array(areMatching, dtype=np.float32)

# %%
# reformat the dataset into pairs of images
train_pairs, train_distance = reformat(train_X, train_y)
test_pairs, test_distance = reformat(test_X, test_y)
# Out:
# 5999
# 999

# %%
# # Show some examples of the training data
# %matplotlib inline
# import matplotlib.pyplot as plt
# import matplotlib.gridspec as gridspec

# # pick 4 random pairs from the training set
# random_indices = np.random.randint(0, len(train_pairs), size=4)
# random_pairs = train_pairs[random_indices]
# random_distance = train_distance[random_indices]

# fig = plt.figure(figsize=(20, 10))
# outer = gridspec.GridSpec(2, 2, wspace=0.2, hspace=0.2)

# for i in range(4):
#   inner = gridspec.GridSpecFromSubplotSpec(1, 2,
#                   subplot_spec=outer[i], wspace=0.1, hspace=0.1)

#   for j in range(2):
#     ax = plt.Subplot(fig, inner[j])
    
#     # show the image
#     ax.imshow(random_pairs[i][j])

#     # show the label
#     ax.text(0, 0, '{}'.format(random_distance[i]),
#             size=24, ha='center', va='center', color='w')

#     ax.set_xticks([])
#     ax.set_yticks([])
#     fig.add_subplot(ax)



# fig.show()

# %%
# Show some examples of the training data
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# pick 4 random pairs from the training set
random_indices = np.random.randint(0, len(train_pairs), size=4)
random_pairs = train_pairs[random_indices]
random_distance = train_distance[random_indices]

fig = plt.figure(figsize=(20, 10))

subFigs = fig.subfigures(2, 2).flatten()

for i in range(4):
  subFig = subFigs[i]
  label = "Match" if random_distance[i] else "miss-Match"
  color = "green" if random_distance[i] else "red"
  subFig.supxlabel(label, fontsize=26, color=color)

  axs = subFig.subplots(1, 2)

  for j in range(2):
    ax = axs[j]
    
    # show the image
    ax.imshow(random_pairs[i][j])

    # show the label
    # ax.text(0, 0, '{}'.format(random_distance[i]),
    #         size=24, ha='center', va='center', color='w')

    ax.set_xticks([])
    ax.set_yticks([])
    subFig.add_subplot(ax)

fig.show()
# Out:
# <ipython-input-85-5ab368570464>:37: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# # How does a siamese network train

# %%
# Train the model
history = model.fit(
  x=[train_pairs[:, 0], train_pairs[:, 1]],
  y=train_distance,
  validation_data=([test_pairs[:, 0], test_pairs[:, 1]], test_distance),
  batch_size=128,
  epochs=10,
  verbose=1
)
# Out:
# Epoch 1/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.1003 - val_loss: 0.1133
# Epoch 2/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.0996 - val_loss: 0.1107
# Epoch 3/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.0986 - val_loss: 0.1117
# Epoch 4/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.0982 - val_loss: 0.1117
# Epoch 5/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.0975 - val_loss: 0.1116
# Epoch 6/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.0969 - val_loss: 0.1115
# Epoch 7/10
# 938/938 [==============================] - 7s 8ms/step - loss: 0.0966 - val_loss: 0.1101
# Epoch 8/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.0962 - val_loss: 0.1088
# Epoch 9/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.0955 - val_loss: 0.1116
# Epoch 10/10
# 938/938 [==============================] - 7s 7ms/step - loss: 0.0954 - val_loss: 0.1107

# %%
# evaluate the model, don't forget the history!
print(model.evaluate(x=[test_pairs[:, 0], test_pairs[:, 1]], y=test_distance, verbose=1))
# Out:
# 625/625 [==============================] - 1s 2ms/step - loss: 0.1107
# 0.11073468625545502

# %%
# let's do some plots!
import matplotlib.pyplot as plt

# pick 4 random pairs from the test set
random_indices = np.random.randint(0, len(test_pairs), size=10)
random_pairs = test_pairs[random_indices]

# predict the distance for each pair
predictions = model.predict([random_pairs[:, 0], random_pairs[:, 1]])

# plot the results
fig = plt.figure(figsize=(20, 10))

subFigs = fig.subfigures(2, 5).flatten()

for i in range(10):
  subFig = subFigs[i]
  distance = predictions[i]
  color = "green" if distance < 0.5 else "red"
  subFig.supxlabel(distance, fontsize=26, color=color)

  axs = subFig.subplots(2, 1)

  for j in range(2):
    ax = axs[j]
    
    # show the image
    ax.imshow(random_pairs[i][j])

    # show the label
    # ax.text(0, 0, '{}'.format(random_distance[i]),
    #         size=24, ha='center', va='center', color='w')

    ax.set_xticks([])
    ax.set_yticks([])
    subFig.add_subplot(ax)

fig.show()
# Out:
# <ipython-input-88-858dd6455cc9>:38: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
